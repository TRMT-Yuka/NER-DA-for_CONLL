# %%
    # MTG 1/6
    #POStagとENTtagの間には何らかの関係性が存在？
    #NERにおけるPOStagアプローチはsimpleと何も変わらないのでは＝＞誤差レベルの違いである可能性が高い
    #構文木のほうにいけるとよいのですが...

# %%
import torch
device = torch.device("cuda:1")

# %% [markdown]
# # data 拡張

# %% [markdown]
# ## train

# %%
with open('data_original/train.txt', 'r', encoding='UTF-8') as f:
    data = f.read()
    data = data.split("\n\n")
    data = data[1:14987] #不要部分をカット

# %%
# storing conll format data in multiple list
document = []
for sentence in data:#14988 sentences
    
    new_sentence_list = []
    sentence_list = sentence.split("\n")
    
    for token in sentence_list:
        token_list = token.split(" ")
        new_sentence_list.append(token_list)
    document.append(new_sentence_list)
    
    # [[['-DOCSTART-', '-X-', '-X-', 'O']],
    #  [['EU', 'NNP', 'B-NP', 'B-ORG'],
    #   ['rejects', 'VBZ', 'B-VP', 'O'],
    #   ['German', 'JJ', 'B-NP', 'B-MISC'],...

# %%
# ['B-ADVP', 'I-ADVP', 'I-ADJP', 'I-SBAR',
#  'I-PP', 'B-LST', 'B-SBAR', 'B-NP',
#  'B-ADJP', 'I-INTJ', 'B-VP', '-X-',
#  'I-CONJP', 'B-PRT', 'B-CONJP', 'I-LST',
#  'B-INTJ', 'B-PP', 'I-VP', 'O', 'I-NP']

# %%
# I-B I-other cut
#    I-I stay 
    
# B-I
#   B-B B-oter cut

# %%
new_document = []
for sentence in document:
    new_sentence_list = []
    
    for i in range(len(sentence)-1):
        new_sentence_list.append(sentence[i])
        
        if "I-" in sentence[i][2]:
            if "I-" in sentence[i+1][2]:
                pass
            else: #B,other
                new_sentence_list.append(-1)
                
        else: #B,other
            if "I-" in sentence[i+1][2]:
                pass
            else: #B,other
                new_sentence_list.append(-1)

    new_document.append(new_sentence_list)

# %%
new_document[0:10]
# Out:
# [[['EU', 'NNP', 'B-NP', 'B-ORG'],
#   -1,
#   ['rejects', 'VBZ', 'B-VP', 'O'],
#   -1,
#   ['German', 'JJ', 'B-NP', 'B-MISC'],
#   ['call', 'NN', 'I-NP', 'O'],
#   -1,
#   ['to', 'TO', 'B-VP', 'O'],
#   ['boycott', 'VB', 'I-VP', 'O'],
#   -1,
#   ['British', 'JJ', 'B-NP', 'B-MISC'],
#   ['lamb', 'NN', 'I-NP', 'O'],
#   -1],
#  [['Peter', 'NNP', 'B-NP', 'B-PER']],
#  [['BRUSSELS', 'NNP', 'B-NP', 'B-LOC']],
#  [['The', 'DT', 'B-NP', 'O'],
#   ['European', 'NNP', 'I-NP', 'B-ORG'],
#   ['Commission', 'NNP', 'I-NP', 'I-ORG'],
#   -1,
#   ['said', 'VBD', 'B-VP', 'O'],
#   -1,
#   ['on', 'IN', 'B-PP', 'O'],
#   -1,
#   ['Thursday', 'NNP', 'B-NP', 'O'],
#   -1,
#   ['it', 'PRP', 'B-NP', 'O'],
#   -1,
#   ['disagreed', 'VBD', 'B-VP', 'O'],
#   -1,
#   ['with', 'IN', 'B-PP', 'O'],
#   -1,
#   ['German', 'JJ', 'B-NP', 'B-MISC'],
#   ['advice', 'NN', 'I-NP', 'O'],
#   -1,
#   ['to', 'TO', 'B-PP', 'O'],
#   -1,
#   ['consumers', 'NNS', 'B-NP', 'O'],
#   -1,
#   ['to', 'TO', 'B-VP', 'O'],
#   ['shun', 'VB', 'I-VP', 'O'],
#   -1,
#   ['British', 'JJ', 'B-NP', 'B-MISC'],
#   ['lamb', 'NN', 'I-NP', 'O'],
#   -1,
#   ['until', 'IN', 'B-SBAR', 'O'],
#   -1,
#   ['scientists', 'NNS', 'B-NP', 'O'],
#   -1,
#   ['determine', 'VBP', 'B-VP', 'O'],
#   -1,
#   ['whether', 'IN', 'B-SBAR', 'O'],
#   -1,
#   ['mad', 'JJ', 'B-NP', 'O'],
#   ['cow', 'NN', 'I-NP', 'O'],
#   ['disease', 'NN', 'I-NP', 'O'],
#   -1,
#   ['can', 'MD', 'B-VP', 'O'],
#   ['be', 'VB', 'I-VP', 'O'],
#   ['transmitted', 'VBN', 'I-VP', 'O'],
#   -1,
#   ['to', 'TO', 'B-PP', 'O'],
#   -1,
#   ['sheep', 'NN', 'B-NP', 'O'],
#   -1],
#  [['Germany', 'NNP', 'B-NP', 'B-LOC'],
#   -1,
#   ["'s", 'POS', 'B-NP', 'O'],
#   ['representative', 'NN', 'I-NP', 'O'],
#   -1,
#   ['to', 'TO', 'B-PP', 'O'],
#   -1,
#   ['the', 'DT', 'B-NP', 'O'],
#   ['European', 'NNP', 'I-NP', 'B-ORG'],
#   ['Union', 'NNP', 'I-NP', 'I-ORG'],
#   -1,
#   ["'s", 'POS', 'B-NP', 'O'],
#   ['veterinary', 'JJ', 'I-NP', 'O'],
#   ['committee', 'NN', 'I-NP', 'O'],
#   ['Werner', 'NNP', 'I-NP', 'B-PER'],
#   ['Zwingmann', 'NNP', 'I-NP', 'I-PER'],
#   -1,
#   ['said', 'VBD', 'B-VP', 'O'],
#   -1,
#   ['on', 'IN', 'B-PP', 'O'],
#   -1,
#   ['Wednesday', 'NNP', 'B-NP', 'O'],
#   ['consumers', 'NNS', 'I-NP', 'O'],
#   -1,
#   ['should', 'MD', 'B-VP', 'O'],
#   ['buy', 'VB', 'I-VP', 'O'],
#   -1,
#   ['sheepmeat', 'NN', 'B-NP', 'O'],
#   -1,
#   ['from', 'IN', 'B-PP', 'O'],
#   -1,
#   ['countries', 'NNS', 'B-NP', 'O'],
#   -1,
#   ['other', 'JJ', 'B-ADJP', 'O'],
#   -1,
#   ['than', 'IN', 'B-PP', 'O'],
#   -1,
#   ['Britain', 'NNP', 'B-NP', 'B-LOC'],
#   -1,
#   ['until', 'IN', 'B-SBAR', 'O'],
#   -1,
#   ['the', 'DT', 'B-NP', 'O'],
#   ['scientific', 'JJ', 'I-NP', 'O'],
#   ['advice', 'NN', 'I-NP', 'O'],
#   -1,
#   ['was', 'VBD', 'B-VP', 'O'],
#   -1,
#   ['clearer', 'JJR', 'B-ADJP', 'O'],
#   -1],
#  [['"', '"', 'O', 'O'],
#   -1,
#   ['We', 'PRP', 'B-NP', 'O'],
#   -1,
#   ['do', 'VBP', 'B-VP', 'O'],
#   ["n't", 'RB', 'I-VP', 'O'],
#   ['support', 'VB', 'I-VP', 'O'],
#   -1,
#   ['any', 'DT', 'B-NP', 'O'],
#   ['such', 'JJ', 'I-NP', 'O'],
#   ['recommendation', 'NN', 'I-NP', 'O'],
#   -1,
#   ['because', 'IN', 'B-SBAR', 'O'],
#   -1,
#   ['we', 'PRP', 'B-NP', 'O'],
#   -1,
#   ['do', 'VBP', 'B-VP', 'O'],
#   ["n't", 'RB', 'I-VP', 'O'],
#   ['see', 'VB', 'I-VP', 'O'],
#   -1,
#   ['any', 'DT', 'B-NP', 'O'],
#   ['grounds', 'NNS', 'I-NP', 'O'],
#   -1,
#   ['for', 'IN', 'B-PP', 'O'],
#   -1,
#   ['it', 'PRP', 'B-NP', 'O'],
#   -1,
#   [',', ',', 'O', 'O'],
#   -1,
#   ['"', '"', 'O', 'O'],
#   -1,
#   ['the', 'DT', 'B-NP', 'O'],
#   ['Commission', 'NNP', 'I-NP', 'B-ORG'],
#   -1,
#   ["'s", 'POS', 'B-NP', 'O'],
#   ['chief', 'JJ', 'I-NP', 'O'],
#   ['spokesman', 'NN', 'I-NP', 'O'],
#   ['Nikolaus', 'NNP', 'I-NP', 'B-PER'],
#   ['van', 'NNP', 'I-NP', 'I-PER'],
#   ['der', 'FW', 'I-NP', 'I-PER'],
#   ['Pas', 'NNP', 'I-NP', 'I-PER'],
#   -1,
#   ['told', 'VBD', 'B-VP', 'O'],
#   -1,
#   ['a', 'DT', 'B-NP', 'O'],
#   ['news', 'NN', 'I-NP', 'O'],
#   ['briefing', 'NN', 'I-NP', 'O'],
#   -1],
#  [['He', 'PRP', 'B-NP', 'O'],
#   -1,
#   ['said', 'VBD', 'B-VP', 'O'],
#   -1,
#   ['further', 'JJ', 'B-NP', 'O'],
#   ['scientific', 'JJ', 'I-NP', 'O'],
#   ['study', 'NN', 'I-NP', 'O'],
#   -1,
#   ['was', 'VBD', 'B-VP', 'O'],
#   ['required', 'VBN', 'I-VP', 'O'],
#   -1,
#   ['and', 'CC', 'O', 'O'],
#   -1,
#   ['if', 'IN', 'B-SBAR', 'O'],
#   -1,
#   ['it', 'PRP', 'B-NP', 'O'],
#   -1,
#   ['was', 'VBD', 'B-VP', 'O'],
#   ['found', 'VBN', 'I-VP', 'O'],
#   -1,
#   ['that', 'IN', 'B-SBAR', 'O'],
#   -1,
#   ['action', 'NN', 'B-NP', 'O'],
#   -1,
#   ['was', 'VBD', 'B-VP', 'O'],
#   ['needed', 'VBN', 'I-VP', 'O'],
#   -1,
#   ['it', 'PRP', 'B-NP', 'O'],
#   -1,
#   ['should', 'MD', 'B-VP', 'O'],
#   ['be', 'VB', 'I-VP', 'O'],
#   ['taken', 'VBN', 'I-VP', 'O'],
#   -1,
#   ['by', 'IN', 'B-PP', 'O'],
#   -1,
#   ['the', 'DT', 'B-NP', 'O'],
#   ['European', 'NNP', 'I-NP', 'B-ORG'],
#   ['Union', 'NNP', 'I-NP', 'I-ORG'],
#   -1],
#  [['He', 'PRP', 'B-NP', 'O'],
#   -1,
#   ['said', 'VBD', 'B-VP', 'O'],
#   -1,
#   ['a', 'DT', 'B-NP', 'O'],
#   ['proposal', 'NN', 'I-NP', 'O'],
#   -1,
#   ['last', 'JJ', 'B-NP', 'O'],
#   ['month', 'NN', 'I-NP', 'O'],
#   -1,
#   ['by', 'IN', 'B-PP', 'O'],
#   -1,
#   ['EU', 'NNP', 'B-NP', 'B-ORG'],
#   ['Farm', 'NNP', 'I-NP', 'O'],
#   ['Commissioner', 'NNP', 'I-NP', 'O'],
#   ['Franz', 'NNP', 'I-NP', 'B-PER'],
#   ['Fischler', 'NNP', 'I-NP', 'I-PER'],
#   -1,
#   ['to', 'TO', 'B-VP', 'O'],
#   ['ban', 'VB', 'I-VP', 'O'],
#   -1,
#   ['sheep', 'NN', 'B-NP', 'O'],
#   ['brains', 'NNS', 'I-NP', 'O'],
#   -1,
#   [',', ',', 'O', 'O'],
#   -1,
#   ['spleens', 'NNS', 'B-NP', 'O'],
#   -1,
#   ['and', 'CC', 'O', 'O'],
#   -1,
#   ['spinal', 'JJ', 'B-NP', 'O'],
#   ['cords', 'NNS', 'I-NP', 'O'],
#   -1,
#   ['from', 'IN', 'B-PP', 'O'],
#   -1,
#   ['the', 'DT', 'B-NP', 'O'],
#   ['human', 'NN', 'I-NP', 'O'],
#   ['and', 'CC', 'I-NP', 'O'],
#   ['animal', 'NN', 'I-NP', 'O'],
#   ['food', 'NN', 'I-NP', 'O'],
#   ['chains', 'NNS', 'I-NP', 'O'],
#   -1,
#   ['was', 'VBD', 'B-VP', 'O'],
#   -1,
#   ['a', 'DT', 'B-NP', 'O'],
#   ['highly', 'RB', 'I-NP', 'O'],
#   -1,
#   ['specific', 'JJ', 'B-ADJP', 'O'],
#   ['and', 'CC', 'I-ADJP', 'O'],
#   ['precautionary', 'JJ', 'I-ADJP', 'O'],
#   -1,
#   ['move', 'NN', 'B-NP', 'O'],
#   -1,
#   ['to', 'TO', 'B-VP', 'O'],
#   ['protect', 'VB', 'I-VP', 'O'],
#   -1,
#   ['human', 'JJ', 'B-NP', 'O'],
#   ['health', 'NN', 'I-NP', 'O'],
#   -1],
#  [['Fischler', 'JJR', 'B-NP', 'B-PER'],
#   ['proposed', 'VBN', 'I-NP', 'O'],
#   ['EU-wide', 'NNP', 'I-NP', 'B-MISC'],
#   -1,
#   ['measures', 'VBZ', 'B-VP', 'O'],
#   -1,
#   ['after', 'IN', 'B-PP', 'O'],
#   -1,
#   ['reports', 'NNS', 'B-NP', 'O'],
#   -1,
#   ['from', 'IN', 'B-PP', 'O'],
#   -1,
#   ['Britain', 'NNP', 'B-NP', 'B-LOC'],
#   ['and', 'CC', 'I-NP', 'O'],
#   ['France', 'NNP', 'I-NP', 'B-LOC'],
#   -1,
#   ['that', 'WDT', 'B-NP', 'O'],
#   -1,
#   ['under', 'IN', 'B-PP', 'O'],
#   -1,
#   ['laboratory', 'NN', 'B-NP', 'O'],
#   -1,
#   ['conditions', 'NNS', 'B-NP', 'O'],
#   ['sheep', 'NN', 'I-NP', 'O'],
#   -1,
#   ['could', 'MD', 'B-VP', 'O'],
#   ['contract', 'VB', 'I-VP', 'O'],
#   -1,
#   ['Bovine', 'NNP', 'B-NP', 'B-MISC'],
#   ['Spongiform', 'NNP', 'I-NP', 'I-MISC'],
#   ['Encephalopathy', 'NNP', 'I-NP', 'I-MISC'],
#   -1,
#   ['(', '(', 'O', 'O'],
#   -1,
#   ['BSE', 'NNP', 'B-NP', 'B-MISC'],
#   -1,
#   [')', ')', 'O', 'O'],
#   -1,
#   ['--', ':', 'O', 'O'],
#   -1,
#   ['mad', 'JJ', 'B-NP', 'O'],
#   ['cow', 'NN', 'I-NP', 'O'],
#   ['disease', 'NN', 'I-NP', 'O'],
#   -1],
#  [['But', 'CC', 'O', 'O'],
#   -1,
#   ['Fischler', 'NNP', 'B-NP', 'B-PER'],
#   -1,
#   ['agreed', 'VBD', 'B-VP', 'O'],
#   ['to', 'TO', 'I-VP', 'O'],
#   ['review', 'VB', 'I-VP', 'O'],
#   -1,
#   ['his', 'PRP$', 'B-NP', 'O'],
#   ['proposal', 'NN', 'I-NP', 'O'],
#   -1,
#   ['after', 'IN', 'B-PP', 'O'],
#   -1,
#   ['the', 'DT', 'B-NP', 'O'],
#   ['EU', 'NNP', 'I-NP', 'B-ORG'],
#   -1,
#   ["'s", 'POS', 'B-NP', 'O'],
#   ['standing', 'NN', 'I-NP', 'O'],
#   ['veterinary', 'JJ', 'I-NP', 'O'],
#   ['committee', 'NN', 'I-NP', 'O'],
#   -1,
#   [',', ',', 'O', 'O'],
#   -1,
#   ['mational', 'JJ', 'B-NP', 'O'],
#   ['animal', 'NN', 'I-NP', 'O'],
#   ['health', 'NN', 'I-NP', 'O'],
#   ['officials', 'NNS', 'I-NP', 'O'],
#   -1,
#   [',', ',', 'O', 'O'],
#   -1,
#   ['questioned', 'VBD', 'B-VP', 'O'],
#   -1,
#   ['if', 'IN', 'B-SBAR', 'O'],
#   -1,
#   ['such', 'JJ', 'B-NP', 'O'],
#   ['action', 'NN', 'I-NP', 'O'],
#   -1,
#   ['was', 'VBD', 'B-VP', 'O'],
#   ['justified', 'VBN', 'I-VP', 'O'],
#   -1,
#   ['as', 'IN', 'B-PP', 'O'],
#   -1,
#   ['there', 'RB', 'B-ADVP', 'O'],
#   -1,
#   ['was', 'VBD', 'B-VP', 'O'],
#   -1,
#   ['only', 'RB', 'B-ADVP', 'O'],
#   -1,
#   ['a', 'DT', 'B-NP', 'O'],
#   ['slight', 'JJ', 'I-NP', 'O'],
#   ['risk', 'NN', 'I-NP', 'O'],
#   -1,
#   ['to', 'TO', 'B-PP', 'O'],
#   -1,
#   ['human', 'JJ', 'B-NP', 'O'],
#   ['health', 'NN', 'I-NP', 'O'],
#   -1]]

# %%
new_new_document = []
for sentence in new_document[0:10]:
    new_sentance = []
    new_tokens = ['']*3
    for token_list in sentence:
        if token_list == -1:
            new_sentance.append(new_tokens)
            new_tokens = ['']*3
        else:
            new_tokens[0] = new_tokens[0]+token_list[0]
            new_tokens[1] = new_tokens[1]+token_list[1]
            new_tokens[2] = new_tokens[2]+token_list[2]
        new_new_document.append(new_sentence_list)

# %%
new_new_document
# Out:
# [[['Swansea', 'NN', 'B-NP', 'B-ORG'],
#   ['1', 'CD', 'I-NP', 'O'],
#   ['Lincoln', 'NNP', 'I-NP', 'B-ORG']],
#  [['Swansea', 'NN', 'B-NP', 'B-ORG'],
#   ['1', 'CD', 'I-NP', 'O'],
#   ['Lincoln', 'NNP', 'I-NP', 'B-ORG']],
#  [['Swansea', 'NN', 'B-NP', 'B-ORG'],
#   ['1', 'CD', 'I-NP', 'O'],
#   ['Lincoln', 'NNP', 'I-NP', 'B-ORG']],
#  [['Swansea', 'NN', 'B-NP', 'B-ORG'],
#   ['1', 'CD', 'I-NP', 'O'],
#   ['Lincoln', 'NNP', 'I-NP', 'B-ORG']],
#  [['Swansea', 'NN', 'B-NP', 'B-ORG'],
#   ['1', 'CD', 'I-NP', 'O'],
#   ['Lincoln', 'NNP', 'I-NP', 'B-ORG']],
#  [['Swansea', 'NN', 'B-NP', 'B-ORG'],
#   ['1', 'CD', 'I-NP', 'O'],
#   ['Lincoln', 'NNP', 'I-NP', 'B-ORG']],
#  [['Swansea', 'NN', 'B-NP', 'B-ORG'],
#   ['1', 'CD', 'I-NP', 'O'],
#   ['Lincoln', 'NNP', 'I-NP', 'B-ORG']],
#  [['Swansea', 'NN', 'B-NP', 'B-ORG'],
#   ['1', 'CD', 'I-NP', 'O'],
#   ['Lincoln', 'NNP', 'I-NP', 'B-ORG']],
#  [['Swansea', 'NN', 'B-NP', 'B-ORG'],
#   ['1', 'CD', 'I-NP', 'O'],
#   ['Lincoln', 'NNP', 'I-NP', 'B-ORG']],
#  [['Swansea', 'NN', 'B-NP', 'B-ORG'],
#   ['1', 'CD', 'I-NP', 'O'],
#   ['Lincoln', 'NNP', 'I-NP', 'B-ORG']],
#  [['Swansea', 'NN', 'B-NP', 'B-ORG'],
#   ['1', 'CD', 'I-NP', 'O'],
#   ['Lincoln', 'NNP', 'I-NP', 'B-ORG']],
#  [['Swansea', 'NN', 'B-NP', 'B-ORG'],
#   ['1', 'CD', 'I-NP', 'O'],
#   ['Lincoln', 'NNP', 'I-NP', 'B-ORG']],
#  [['Swansea', 'NN', 'B-NP', 'B-ORG'],
#   ['1', 'CD', 'I-NP', 'O'],
#   ['Lincoln', 'NNP', 'I-NP', 'B-ORG']],
#  [['Swansea', 'NN', 'B-NP', 'B-ORG'],
#   ['1', 'CD', 'I-NP', 'O'],
#   ['Lincoln', 'NNP', 'I-NP', 'B-ORG']],
#  [['Swansea', 'NN', 'B-NP', 'B-ORG'],
#   ['1', 'CD', 'I-NP', 'O'],
#   ['Lincoln', 'NNP', 'I-NP', 'B-ORG']],
#  [['Swansea', 'NN', 'B-NP', 'B-ORG'],
#   ['1', 'CD', 'I-NP', 'O'],
#   ['Lincoln', 'NNP', 'I-NP', 'B-ORG']],
#  [['Swansea', 'NN', 'B-NP', 'B-ORG'],
#   ['1', 'CD', 'I-NP', 'O'],
#   ['Lincoln', 'NNP', 'I-NP', 'B-ORG']],
#  [['Swansea', 'NN', 'B-NP', 'B-ORG'],
#   ['1', 'CD', 'I-NP', 'O'],
#   ['Lincoln', 'NNP', 'I-NP', 'B-ORG']],
#  [['Swansea', 'NN', 'B-NP', 'B-ORG'],
#   ['1', 'CD', 'I-NP', 'O'],
#   ['Lincoln', 'NNP', 'I-NP', 'B-ORG']],
#  [['Swansea', 'NN', 'B-NP', 'B-ORG'],
#   ['1', 'CD', 'I-NP', 'O'],
#   ['Lincoln', 'NNP', 'I-NP', 'B-ORG']],
#  [['Swansea', 'NN', 'B-NP', 'B-ORG'],
#   ['1', 'CD', 'I-NP', 'O'],
#   ['Lincoln', 'NNP', 'I-NP', 'B-ORG']],
#  [['Swansea', 'NN', 'B-NP', 'B-ORG'],
#   ['1', 'CD', 'I-NP', 'O'],
#   ['Lincoln', 'NNP', 'I-NP', 'B-ORG']],
#  [['Swansea', 'NN', 'B-NP', 'B-ORG'],
#   ['1', 'CD', 'I-NP', 'O'],
#   ['Lincoln', 'NNP', 'I-NP', 'B-ORG']],
#  [['Swansea', 'NN', 'B-NP', 'B-ORG'],
#   ['1', 'CD', 'I-NP', 'O'],
#   ['Lincoln', 'NNP', 'I-NP', 'B-ORG']],
#  [['Swansea', 'NN', 'B-NP', 'B-ORG'],
#   ['1', 'CD', 'I-NP', 'O'],
#   ['Lincoln', 'NNP', 'I-NP', 'B-ORG']],
#  [['Swansea', 'NN', 'B-NP', 'B-ORG'],
#   ['1', 'CD', 'I-NP', 'O'],
#   ['Lincoln', 'NNP', 'I-NP', 'B-ORG']],
#  [['Swansea', 'NN', 'B-NP', 'B-ORG'],
#   ['1', 'CD', 'I-NP', 'O'],
#   ['Lincoln', 'NNP', 'I-NP', 'B-ORG']],
#  [['Swansea', 'NN', 'B-NP', 'B-ORG'],
#   ['1', 'CD', 'I-NP', 'O'],
#   ['Lincoln', 'NNP', 'I-NP', 'B-ORG']],
#  [['Swansea', 'NN', 'B-NP', 'B-ORG'],
#   ['1', 'CD', 'I-NP', 'O'],
#   ['Lincoln', 'NNP', 'I-NP', 'B-ORG']],
#  [['Swansea', 'NN', 'B-NP', 'B-ORG'],
#   ['1', 'CD', 'I-NP', 'O'],
#   ['Lincoln', 'NNP', 'I-NP', 'B-ORG']],
#  [['Swansea', 'NN', 'B-NP', 'B-ORG'],
#   ['1', 'CD', 'I-NP', 'O'],
#   ['Lincoln', 'NNP', 'I-NP', 'B-ORG']],
#  [['Swansea', 'NN', 'B-NP', 'B-ORG'],
#   ['1', 'CD', 'I-NP', 'O'],
#   ['Lincoln', 'NNP', 'I-NP', 'B-ORG']],
#  [['Swansea', 'NN', 'B-NP', 'B-ORG'],
#   ['1', 'CD', 'I-NP', 'O'],
#   ['Lincoln', 'NNP', 'I-NP', 'B-ORG']],
#  [['Swansea', 'NN', 'B-NP', 'B-ORG'],
#   ['1', 'CD', 'I-NP', 'O'],
#   ['Lincoln', 'NNP', 'I-NP', 'B-ORG']],
#  [['Swansea', 'NN', 'B-NP', 'B-ORG'],
#   ['1', 'CD', 'I-NP', 'O'],
#   ['Lincoln', 'NNP', 'I-NP', 'B-ORG']],
#  [['Swansea', 'NN', 'B-NP', 'B-ORG'],
#   ['1', 'CD', 'I-NP', 'O'],
#   ['Lincoln', 'NNP', 'I-NP', 'B-ORG']],
#  [['Swansea', 'NN', 'B-NP', 'B-ORG'],
#   ['1', 'CD', 'I-NP', 'O'],
#   ['Lincoln', 'NNP', 'I-NP', 'B-ORG']],
#  [['Swansea', 'NN', 'B-NP', 'B-ORG'],
#   ['1', 'CD', 'I-NP', 'O'],
#   ['Lincoln', 'NNP', 'I-NP', 'B-ORG']],
#  [['Swansea', 'NN', 'B-NP', 'B-ORG'],
#   ['1', 'CD', 'I-NP', 'O'],
#   ['Lincoln', 'NNP', 'I-NP', 'B-ORG']],
#  [['Swansea', 'NN', 'B-NP', 'B-ORG'],
#   ['1', 'CD', 'I-NP', 'O'],
#   ['Lincoln', 'NNP', 'I-NP', 'B-ORG']],
#  [['Swansea', 'NN', 'B-NP', 'B-ORG'],
#   ['1', 'CD', 'I-NP', 'O'],
#   ['Lincoln', 'NNP', 'I-NP', 'B-ORG']],
#  [['Swansea', 'NN', 'B-NP', 'B-ORG'],
#   ['1', 'CD', 'I-NP', 'O'],
#   ['Lincoln', 'NNP', 'I-NP', 'B-ORG']],
#  [['Swansea', 'NN', 'B-NP', 'B-ORG'],
#   ['1', 'CD', 'I-NP', 'O'],
#   ['Lincoln', 'NNP', 'I-NP', 'B-ORG']],
#  [['Swansea', 'NN', 'B-NP', 'B-ORG'],
#   ['1', 'CD', 'I-NP', 'O'],
#   ['Lincoln', 'NNP', 'I-NP', 'B-ORG']],
#  [['Swansea', 'NN', 'B-NP', 'B-ORG'],
#   ['1', 'CD', 'I-NP', 'O'],
#   ['Lincoln', 'NNP', 'I-NP', 'B-ORG']],
#  [['Swansea', 'NN', 'B-NP', 'B-ORG'],
#   ['1', 'CD', 'I-NP', 'O'],
#   ['Lincoln', 'NNP', 'I-NP', 'B-ORG']],
#  [['Swansea', 'NN', 'B-NP', 'B-ORG'],
#   ['1', 'CD', 'I-NP', 'O'],
#   ['Lincoln', 'NNP', 'I-NP', 'B-ORG']],
#  [['Swansea', 'NN', 'B-NP', 'B-ORG'],
#   ['1', 'CD', 'I-NP', 'O'],
#   ['Lincoln', 'NNP', 'I-NP', 'B-ORG']],
#  [['Swansea', 'NN', 'B-NP', 'B-ORG'],
#   ['1', 'CD', 'I-NP', 'O'],
#   ['Lincoln', 'NNP', 'I-NP', 'B-ORG']],
#  [['Swansea', 'NN', 'B-NP', 'B-ORG'],
#   ['1', 'CD', 'I-NP', 'O'],
#   ['Lincoln', 'NNP', 'I-NP', 'B-ORG']],
#  [['Swansea', 'NN', 'B-NP', 'B-ORG'],
#   ['1', 'CD', 'I-NP', 'O'],
#   ['Lincoln', 'NNP', 'I-NP', 'B-ORG']],
#  [['Swansea', 'NN', 'B-NP', 'B-ORG'],
#   ['1', 'CD', 'I-NP', 'O'],
#   ['Lincoln', 'NNP', 'I-NP', 'B-ORG']],
#  [['Swansea', 'NN', 'B-NP', 'B-ORG'],
#   ['1', 'CD', 'I-NP', 'O'],
#   ['Lincoln', 'NNP', 'I-NP', 'B-ORG']],
#  [['Swansea', 'NN', 'B-NP', 'B-ORG'],
#   ['1', 'CD', 'I-NP', 'O'],
#   ['Lincoln', 'NNP', 'I-NP', 'B-ORG']],
#  [['Swansea', 'NN', 'B-NP', 'B-ORG'],
#   ['1', 'CD', 'I-NP', 'O'],
#   ['Lincoln', 'NNP', 'I-NP', 'B-ORG']],
#  [['Swansea', 'NN', 'B-NP', 'B-ORG'],
#   ['1', 'CD', 'I-NP', 'O'],
#   ['Lincoln', 'NNP', 'I-NP', 'B-ORG']],
#  [['Swansea', 'NN', 'B-NP', 'B-ORG'],
#   ['1', 'CD', 'I-NP', 'O'],
#   ['Lincoln', 'NNP', 'I-NP', 'B-ORG']],
#  [['Swansea', 'NN', 'B-NP', 'B-ORG'],
#   ['1', 'CD', 'I-NP', 'O'],
#   ['Lincoln', 'NNP', 'I-NP', 'B-ORG']],
#  [['Swansea', 'NN', 'B-NP', 'B-ORG'],
#   ['1', 'CD', 'I-NP', 'O'],
#   ['Lincoln', 'NNP', 'I-NP', 'B-ORG']],
#  [['Swansea', 'NN', 'B-NP', 'B-ORG'],
#   ['1', 'CD', 'I-NP', 'O'],
#   ['Lincoln', 'NNP', 'I-NP', 'B-ORG']],
#  [['Swansea', 'NN', 'B-NP', 'B-ORG'],
#   ['1', 'CD', 'I-NP', 'O'],
#   ['Lincoln', 'NNP', 'I-NP', 'B-ORG']],
#  [['Swansea', 'NN', 'B-NP', 'B-ORG'],
#   ['1', 'CD', 'I-NP', 'O'],
#   ['Lincoln', 'NNP', 'I-NP', 'B-ORG']],
#  [['Swansea', 'NN', 'B-NP', 'B-ORG'],
#   ['1', 'CD', 'I-NP', 'O'],
#   ['Lincoln', 'NNP', 'I-NP', 'B-ORG']],
#  [['Swansea', 'NN', 'B-NP', 'B-ORG'],
#   ['1', 'CD', 'I-NP', 'O'],
#   ['Lincoln', 'NNP', 'I-NP', 'B-ORG']],
#  [['Swansea', 'NN', 'B-NP', 'B-ORG'],
#   ['1', 'CD', 'I-NP', 'O'],
#   ['Lincoln', 'NNP', 'I-NP', 'B-ORG']],
#  [['Swansea', 'NN', 'B-NP', 'B-ORG'],
#   ['1', 'CD', 'I-NP', 'O'],
#   ['Lincoln', 'NNP', 'I-NP', 'B-ORG']],
#  [['Swansea', 'NN', 'B-NP', 'B-ORG'],
#   ['1', 'CD', 'I-NP', 'O'],
#   ['Lincoln', 'NNP', 'I-NP', 'B-ORG']],
#  [['Swansea', 'NN', 'B-NP', 'B-ORG'],
#   ['1', 'CD', 'I-NP', 'O'],
#   ['Lincoln', 'NNP', 'I-NP', 'B-ORG']],
#  [['Swansea', 'NN', 'B-NP', 'B-ORG'],
#   ['1', 'CD', 'I-NP', 'O'],
#   ['Lincoln', 'NNP', 'I-NP', 'B-ORG']],
#  [['Swansea', 'NN', 'B-NP', 'B-ORG'],
#   ['1', 'CD', 'I-NP', 'O'],
#   ['Lincoln', 'NNP', 'I-NP', 'B-ORG']],
#  [['Swansea', 'NN', 'B-NP', 'B-ORG'],
#   ['1', 'CD', 'I-NP', 'O'],
#   ['Lincoln', 'NNP', 'I-NP', 'B-ORG']],
#  [['Swansea', 'NN', 'B-NP', 'B-ORG'],
#   ['1', 'CD', 'I-NP', 'O'],
#   ['Lincoln', 'NNP', 'I-NP', 'B-ORG']],
#  [['Swansea', 'NN', 'B-NP', 'B-ORG'],
#   ['1', 'CD', 'I-NP', 'O'],
#   ['Lincoln', 'NNP', 'I-NP', 'B-ORG']],
#  [['Swansea', 'NN', 'B-NP', 'B-ORG'],
#   ['1', 'CD', 'I-NP', 'O'],
#   ['Lincoln', 'NNP', 'I-NP', 'B-ORG']],
#  [['Swansea', 'NN', 'B-NP', 'B-ORG'],
#   ['1', 'CD', 'I-NP', 'O'],
#   ['Lincoln', 'NNP', 'I-NP', 'B-ORG']],
#  [['Swansea', 'NN', 'B-NP', 'B-ORG'],
#   ['1', 'CD', 'I-NP', 'O'],
#   ['Lincoln', 'NNP', 'I-NP', 'B-ORG']],
#  [['Swansea', 'NN', 'B-NP', 'B-ORG'],
#   ['1', 'CD', 'I-NP', 'O'],
#   ['Lincoln', 'NNP', 'I-NP', 'B-ORG']],
#  [['Swansea', 'NN', 'B-NP', 'B-ORG'],
#   ['1', 'CD', 'I-NP', 'O'],
#   ['Lincoln', 'NNP', 'I-NP', 'B-ORG']],
#  [['Swansea', 'NN', 'B-NP', 'B-ORG'],
#   ['1', 'CD', 'I-NP', 'O'],
#   ['Lincoln', 'NNP', 'I-NP', 'B-ORG']],
#  [['Swansea', 'NN', 'B-NP', 'B-ORG'],
#   ['1', 'CD', 'I-NP', 'O'],
#   ['Lincoln', 'NNP', 'I-NP', 'B-ORG']],
#  [['Swansea', 'NN', 'B-NP', 'B-ORG'],
#   ['1', 'CD', 'I-NP', 'O'],
#   ['Lincoln', 'NNP', 'I-NP', 'B-ORG']],
#  [['Swansea', 'NN', 'B-NP', 'B-ORG'],
#   ['1', 'CD', 'I-NP', 'O'],
#   ['Lincoln', 'NNP', 'I-NP', 'B-ORG']],
#  [['Swansea', 'NN', 'B-NP', 'B-ORG'],
#   ['1', 'CD', 'I-NP', 'O'],
#   ['Lincoln', 'NNP', 'I-NP', 'B-ORG']],
#  [['Swansea', 'NN', 'B-NP', 'B-ORG'],
#   ['1', 'CD', 'I-NP', 'O'],
#   ['Lincoln', 'NNP', 'I-NP', 'B-ORG']],
#  [['Swansea', 'NN', 'B-NP', 'B-ORG'],
#   ['1', 'CD', 'I-NP', 'O'],
#   ['Lincoln', 'NNP', 'I-NP', 'B-ORG']],
#  [['Swansea', 'NN', 'B-NP', 'B-ORG'],
#   ['1', 'CD', 'I-NP', 'O'],
#   ['Lincoln', 'NNP', 'I-NP', 'B-ORG']],
#  [['Swansea', 'NN', 'B-NP', 'B-ORG'],
#   ['1', 'CD', 'I-NP', 'O'],
#   ['Lincoln', 'NNP', 'I-NP', 'B-ORG']],
#  [['Swansea', 'NN', 'B-NP', 'B-ORG'],
#   ['1', 'CD', 'I-NP', 'O'],
#   ['Lincoln', 'NNP', 'I-NP', 'B-ORG']],
#  [['Swansea', 'NN', 'B-NP', 'B-ORG'],
#   ['1', 'CD', 'I-NP', 'O'],
#   ['Lincoln', 'NNP', 'I-NP', 'B-ORG']],
#  [['Swansea', 'NN', 'B-NP', 'B-ORG'],
#   ['1', 'CD', 'I-NP', 'O'],
#   ['Lincoln', 'NNP', 'I-NP', 'B-ORG']],
#  [['Swansea', 'NN', 'B-NP', 'B-ORG'],
#   ['1', 'CD', 'I-NP', 'O'],
#   ['Lincoln', 'NNP', 'I-NP', 'B-ORG']],
#  [['Swansea', 'NN', 'B-NP', 'B-ORG'],
#   ['1', 'CD', 'I-NP', 'O'],
#   ['Lincoln', 'NNP', 'I-NP', 'B-ORG']],
#  [['Swansea', 'NN', 'B-NP', 'B-ORG'],
#   ['1', 'CD', 'I-NP', 'O'],
#   ['Lincoln', 'NNP', 'I-NP', 'B-ORG']],
#  [['Swansea', 'NN', 'B-NP', 'B-ORG'],
#   ['1', 'CD', 'I-NP', 'O'],
#   ['Lincoln', 'NNP', 'I-NP', 'B-ORG']],
#  [['Swansea', 'NN', 'B-NP', 'B-ORG'],
#   ['1', 'CD', 'I-NP', 'O'],
#   ['Lincoln', 'NNP', 'I-NP', 'B-ORG']],
#  [['Swansea', 'NN', 'B-NP', 'B-ORG'],
#   ['1', 'CD', 'I-NP', 'O'],
#   ['Lincoln', 'NNP', 'I-NP', 'B-ORG']],
#  [['Swansea', 'NN', 'B-NP', 'B-ORG'],
#   ['1', 'CD', 'I-NP', 'O'],
#   ['Lincoln', 'NNP', 'I-NP', 'B-ORG']],
#  [['Swansea', 'NN', 'B-NP', 'B-ORG'],
#   ['1', 'CD', 'I-NP', 'O'],
#   ['Lincoln', 'NNP', 'I-NP', 'B-ORG']],
#  [['Swansea', 'NN', 'B-NP', 'B-ORG'],
#   ['1', 'CD', 'I-NP', 'O'],
#   ['Lincoln', 'NNP', 'I-NP', 'B-ORG']],
#  [['Swansea', 'NN', 'B-NP', 'B-ORG'],
#   ['1', 'CD', 'I-NP', 'O'],
#   ['Lincoln', 'NNP', 'I-NP', 'B-ORG']],
#  [['Swansea', 'NN', 'B-NP', 'B-ORG'],
#   ['1', 'CD', 'I-NP', 'O'],
#   ['Lincoln', 'NNP', 'I-NP', 'B-ORG']],
#  [['Swansea', 'NN', 'B-NP', 'B-ORG'],
#   ['1', 'CD', 'I-NP', 'O'],
#   ['Lincoln', 'NNP', 'I-NP', 'B-ORG']],
#  [['Swansea', 'NN', 'B-NP', 'B-ORG'],
#   ['1', 'CD', 'I-NP', 'O'],
#   ['Lincoln', 'NNP', 'I-NP', 'B-ORG']],
#  [['Swansea', 'NN', 'B-NP', 'B-ORG'],
#   ['1', 'CD', 'I-NP', 'O'],
#   ['Lincoln', 'NNP', 'I-NP', 'B-ORG']],
#  [['Swansea', 'NN', 'B-NP', 'B-ORG'],
#   ['1', 'CD', 'I-NP', 'O'],
#   ['Lincoln', 'NNP', 'I-NP', 'B-ORG']],
#  [['Swansea', 'NN', 'B-NP', 'B-ORG'],
#   ['1', 'CD', 'I-NP', 'O'],
#   ['Lincoln', 'NNP', 'I-NP', 'B-ORG']],
#  [['Swansea', 'NN', 'B-NP', 'B-ORG'],
#   ['1', 'CD', 'I-NP', 'O'],
#   ['Lincoln', 'NNP', 'I-NP', 'B-ORG']],
#  [['Swansea', 'NN', 'B-NP', 'B-ORG'],
#   ['1', 'CD', 'I-NP', 'O'],
#   ['Lincoln', 'NNP', 'I-NP', 'B-ORG']],
#  [['Swansea', 'NN', 'B-NP', 'B-ORG'],
#   ['1', 'CD', 'I-NP', 'O'],
#   ['Lincoln', 'NNP', 'I-NP', 'B-ORG']],
#  [['Swansea', 'NN', 'B-NP', 'B-ORG'],
#   ['1', 'CD', 'I-NP', 'O'],
#   ['Lincoln', 'NNP', 'I-NP', 'B-ORG']],
#  [['Swansea', 'NN', 'B-NP', 'B-ORG'],
#   ['1', 'CD', 'I-NP', 'O'],
#   ['Lincoln', 'NNP', 'I-NP', 'B-ORG']],
#  [['Swansea', 'NN', 'B-NP', 'B-ORG'],
#   ['1', 'CD', 'I-NP', 'O'],
#   ['Lincoln', 'NNP', 'I-NP', 'B-ORG']],
#  [['Swansea', 'NN', 'B-NP', 'B-ORG'],
#   ['1', 'CD', 'I-NP', 'O'],
#   ['Lincoln', 'NNP', 'I-NP', 'B-ORG']],
#  [['Swansea', 'NN', 'B-NP', 'B-ORG'],
#   ['1', 'CD', 'I-NP', 'O'],
#   ['Lincoln', 'NNP', 'I-NP', 'B-ORG']],
#  [['Swansea', 'NN', 'B-NP', 'B-ORG'],
#   ['1', 'CD', 'I-NP', 'O'],
#   ['Lincoln', 'NNP', 'I-NP', 'B-ORG']],
#  [['Swansea', 'NN', 'B-NP', 'B-ORG'],
#   ['1', 'CD', 'I-NP', 'O'],
#   ['Lincoln', 'NNP', 'I-NP', 'B-ORG']],
#  [['Swansea', 'NN', 'B-NP', 'B-ORG'],
#   ['1', 'CD', 'I-NP', 'O'],
#   ['Lincoln', 'NNP', 'I-NP', 'B-ORG']],
#  [['Swansea', 'NN', 'B-NP', 'B-ORG'],
#   ['1', 'CD', 'I-NP', 'O'],
#   ['Lincoln', 'NNP', 'I-NP', 'B-ORG']],
#  [['Swansea', 'NN', 'B-NP', 'B-ORG'],
#   ['1', 'CD', 'I-NP', 'O'],
#   ['Lincoln', 'NNP', 'I-NP', 'B-ORG']],
#  [['Swansea', 'NN', 'B-NP', 'B-ORG'],
#   ['1', 'CD', 'I-NP', 'O'],
#   ['Lincoln', 'NNP', 'I-NP', 'B-ORG']],
#  [['Swansea', 'NN', 'B-NP', 'B-ORG'],
#   ['1', 'CD', 'I-NP', 'O'],
#   ['Lincoln', 'NNP', 'I-NP', 'B-ORG']],
#  [['Swansea', 'NN', 'B-NP', 'B-ORG'],
#   ['1', 'CD', 'I-NP', 'O'],
#   ['Lincoln', 'NNP', 'I-NP', 'B-ORG']],
#  [['Swansea', 'NN', 'B-NP', 'B-ORG'],
#   ['1', 'CD', 'I-NP', 'O'],
#   ['Lincoln', 'NNP', 'I-NP', 'B-ORG']],
#  [['Swansea', 'NN', 'B-NP', 'B-ORG'],
#   ['1', 'CD', 'I-NP', 'O'],
#   ['Lincoln', 'NNP', 'I-NP', 'B-ORG']],
#  [['Swansea', 'NN', 'B-NP', 'B-ORG'],
#   ['1', 'CD', 'I-NP', 'O'],
#   ['Lincoln', 'NNP', 'I-NP', 'B-ORG']],
#  [['Swansea', 'NN', 'B-NP', 'B-ORG'],
#   ['1', 'CD', 'I-NP', 'O'],
#   ['Lincoln', 'NNP', 'I-NP', 'B-ORG']],
#  [['Swansea', 'NN', 'B-NP', 'B-ORG'],
#   ['1', 'CD', 'I-NP', 'O'],
#   ['Lincoln', 'NNP', 'I-NP', 'B-ORG']],
#  [['Swansea', 'NN', 'B-NP', 'B-ORG'],
#   ['1', 'CD', 'I-NP', 'O'],
#   ['Lincoln', 'NNP', 'I-NP', 'B-ORG']],
#  [['Swansea', 'NN', 'B-NP', 'B-ORG'],
#   ['1', 'CD', 'I-NP', 'O'],
#   ['Lincoln', 'NNP', 'I-NP', 'B-ORG']],
#  [['Swansea', 'NN', 'B-NP', 'B-ORG'],
#   ['1', 'CD', 'I-NP', 'O'],
#   ['Lincoln', 'NNP', 'I-NP', 'B-ORG']],
#  [['Swansea', 'NN', 'B-NP', 'B-ORG'],
#   ['1', 'CD', 'I-NP', 'O'],
#   ['Lincoln', 'NNP', 'I-NP', 'B-ORG']],
#  [['Swansea', 'NN', 'B-NP', 'B-ORG'],
#   ['1', 'CD', 'I-NP', 'O'],
#   ['Lincoln', 'NNP', 'I-NP', 'B-ORG']],
#  [['Swansea', 'NN', 'B-NP', 'B-ORG'],
#   ['1', 'CD', 'I-NP', 'O'],
#   ['Lincoln', 'NNP', 'I-NP', 'B-ORG']],
#  [['Swansea', 'NN', 'B-NP', 'B-ORG'],
#   ['1', 'CD', 'I-NP', 'O'],
#   ['Lincoln', 'NNP', 'I-NP', 'B-ORG']],
#  [['Swansea', 'NN', 'B-NP', 'B-ORG'],
#   ['1', 'CD', 'I-NP', 'O'],
#   ['Lincoln', 'NNP', 'I-NP', 'B-ORG']],
#  [['Swansea', 'NN', 'B-NP', 'B-ORG'],
#   ['1', 'CD', 'I-NP', 'O'],
#   ['Lincoln', 'NNP', 'I-NP', 'B-ORG']],
#  [['Swansea', 'NN', 'B-NP', 'B-ORG'],
#   ['1', 'CD', 'I-NP', 'O'],
#   ['Lincoln', 'NNP', 'I-NP', 'B-ORG']],
#  [['Swansea', 'NN', 'B-NP', 'B-ORG'],
#   ['1', 'CD', 'I-NP', 'O'],
#   ['Lincoln', 'NNP', 'I-NP', 'B-ORG']],
#  [['Swansea', 'NN', 'B-NP', 'B-ORG'],
#   ['1', 'CD', 'I-NP', 'O'],
#   ['Lincoln', 'NNP', 'I-NP', 'B-ORG']],
#  [['Swansea', 'NN', 'B-NP', 'B-ORG'],
#   ['1', 'CD', 'I-NP', 'O'],
#   ['Lincoln', 'NNP', 'I-NP', 'B-ORG']],
#  [['Swansea', 'NN', 'B-NP', 'B-ORG'],
#   ['1', 'CD', 'I-NP', 'O'],
#   ['Lincoln', 'NNP', 'I-NP', 'B-ORG']],
#  [['Swansea', 'NN', 'B-NP', 'B-ORG'],
#   ['1', 'CD', 'I-NP', 'O'],
#   ['Lincoln', 'NNP', 'I-NP', 'B-ORG']],
#  [['Swansea', 'NN', 'B-NP', 'B-ORG'],
#   ['1', 'CD', 'I-NP', 'O'],
#   ['Lincoln', 'NNP', 'I-NP', 'B-ORG']],
#  [['Swansea', 'NN', 'B-NP', 'B-ORG'],
#   ['1', 'CD', 'I-NP', 'O'],
#   ['Lincoln', 'NNP', 'I-NP', 'B-ORG']],
#  [['Swansea', 'NN', 'B-NP', 'B-ORG'],
#   ['1', 'CD', 'I-NP', 'O'],
#   ['Lincoln', 'NNP', 'I-NP', 'B-ORG']],
#  [['Swansea', 'NN', 'B-NP', 'B-ORG'],
#   ['1', 'CD', 'I-NP', 'O'],
#   ['Lincoln', 'NNP', 'I-NP', 'B-ORG']],
#  [['Swansea', 'NN', 'B-NP', 'B-ORG'],
#   ['1', 'CD', 'I-NP', 'O'],
#   ['Lincoln', 'NNP', 'I-NP', 'B-ORG']],
#  [['Swansea', 'NN', 'B-NP', 'B-ORG'],
#   ['1', 'CD', 'I-NP', 'O'],
#   ['Lincoln', 'NNP', 'I-NP', 'B-ORG']],
#  [['Swansea', 'NN', 'B-NP', 'B-ORG'],
#   ['1', 'CD', 'I-NP', 'O'],
#   ['Lincoln', 'NNP', 'I-NP', 'B-ORG']],
#  [['Swansea', 'NN', 'B-NP', 'B-ORG'],
#   ['1', 'CD', 'I-NP', 'O'],
#   ['Lincoln', 'NNP', 'I-NP', 'B-ORG']],
#  [['Swansea', 'NN', 'B-NP', 'B-ORG'],
#   ['1', 'CD', 'I-NP', 'O'],
#   ['Lincoln', 'NNP', 'I-NP', 'B-ORG']],
#  [['Swansea', 'NN', 'B-NP', 'B-ORG'],
#   ['1', 'CD', 'I-NP', 'O'],
#   ['Lincoln', 'NNP', 'I-NP', 'B-ORG']],
#  [['Swansea', 'NN', 'B-NP', 'B-ORG'],
#   ['1', 'CD', 'I-NP', 'O'],
#   ['Lincoln', 'NNP', 'I-NP', 'B-ORG']],
#  [['Swansea', 'NN', 'B-NP', 'B-ORG'],
#   ['1', 'CD', 'I-NP', 'O'],
#   ['Lincoln', 'NNP', 'I-NP', 'B-ORG']],
#  [['Swansea', 'NN', 'B-NP', 'B-ORG'],
#   ['1', 'CD', 'I-NP', 'O'],
#   ['Lincoln', 'NNP', 'I-NP', 'B-ORG']],
#  [['Swansea', 'NN', 'B-NP', 'B-ORG'],
#   ['1', 'CD', 'I-NP', 'O'],
#   ['Lincoln', 'NNP', 'I-NP', 'B-ORG']],
#  [['Swansea', 'NN', 'B-NP', 'B-ORG'],
#   ['1', 'CD', 'I-NP', 'O'],
#   ['Lincoln', 'NNP', 'I-NP', 'B-ORG']],
#  [['Swansea', 'NN', 'B-NP', 'B-ORG'],
#   ['1', 'CD', 'I-NP', 'O'],
#   ['Lincoln', 'NNP', 'I-NP', 'B-ORG']],
#  [['Swansea', 'NN', 'B-NP', 'B-ORG'],
#   ['1', 'CD', 'I-NP', 'O'],
#   ['Lincoln', 'NNP', 'I-NP', 'B-ORG']],
#  [['Swansea', 'NN', 'B-NP', 'B-ORG'],
#   ['1', 'CD', 'I-NP', 'O'],
#   ['Lincoln', 'NNP', 'I-NP', 'B-ORG']],
#  [['Swansea', 'NN', 'B-NP', 'B-ORG'],
#   ['1', 'CD', 'I-NP', 'O'],
#   ['Lincoln', 'NNP', 'I-NP', 'B-ORG']],
#  [['Swansea', 'NN', 'B-NP', 'B-ORG'],
#   ['1', 'CD', 'I-NP', 'O'],
#   ['Lincoln', 'NNP', 'I-NP', 'B-ORG']],
#  [['Swansea', 'NN', 'B-NP', 'B-ORG'],
#   ['1', 'CD', 'I-NP', 'O'],
#   ['Lincoln', 'NNP', 'I-NP', 'B-ORG']],
#  [['Swansea', 'NN', 'B-NP', 'B-ORG'],
#   ['1', 'CD', 'I-NP', 'O'],
#   ['Lincoln', 'NNP', 'I-NP', 'B-ORG']],
#  [['Swansea', 'NN', 'B-NP', 'B-ORG'],
#   ['1', 'CD', 'I-NP', 'O'],
#   ['Lincoln', 'NNP', 'I-NP', 'B-ORG']],
#  [['Swansea', 'NN', 'B-NP', 'B-ORG'],
#   ['1', 'CD', 'I-NP', 'O'],
#   ['Lincoln', 'NNP', 'I-NP', 'B-ORG']],
#  [['Swansea', 'NN', 'B-NP', 'B-ORG'],
#   ['1', 'CD', 'I-NP', 'O'],
#   ['Lincoln', 'NNP', 'I-NP', 'B-ORG']],
#  [['Swansea', 'NN', 'B-NP', 'B-ORG'],
#   ['1', 'CD', 'I-NP', 'O'],
#   ['Lincoln', 'NNP', 'I-NP', 'B-ORG']],
#  [['Swansea', 'NN', 'B-NP', 'B-ORG'],
#   ['1', 'CD', 'I-NP', 'O'],
#   ['Lincoln', 'NNP', 'I-NP', 'B-ORG']],
#  [['Swansea', 'NN', 'B-NP', 'B-ORG'],
#   ['1', 'CD', 'I-NP', 'O'],
#   ['Lincoln', 'NNP', 'I-NP', 'B-ORG']],
#  [['Swansea', 'NN', 'B-NP', 'B-ORG'],
#   ['1', 'CD', 'I-NP', 'O'],
#   ['Lincoln', 'NNP', 'I-NP', 'B-ORG']],
#  [['Swansea', 'NN', 'B-NP', 'B-ORG'],
#   ['1', 'CD', 'I-NP', 'O'],
#   ['Lincoln', 'NNP', 'I-NP', 'B-ORG']],
#  [['Swansea', 'NN', 'B-NP', 'B-ORG'],
#   ['1', 'CD', 'I-NP', 'O'],
#   ['Lincoln', 'NNP', 'I-NP', 'B-ORG']],
#  [['Swansea', 'NN', 'B-NP', 'B-ORG'],
#   ['1', 'CD', 'I-NP', 'O'],
#   ['Lincoln', 'NNP', 'I-NP', 'B-ORG']],
#  [['Swansea', 'NN', 'B-NP', 'B-ORG'],
#   ['1', 'CD', 'I-NP', 'O'],
#   ['Lincoln', 'NNP', 'I-NP', 'B-ORG']],
#  [['Swansea', 'NN', 'B-NP', 'B-ORG'],
#   ['1', 'CD', 'I-NP', 'O'],
#   ['Lincoln', 'NNP', 'I-NP', 'B-ORG']],
#  [['Swansea', 'NN', 'B-NP', 'B-ORG'],
#   ['1', 'CD', 'I-NP', 'O'],
#   ['Lincoln', 'NNP', 'I-NP', 'B-ORG']],
#  [['Swansea', 'NN', 'B-NP', 'B-ORG'],
#   ['1', 'CD', 'I-NP', 'O'],
#   ['Lincoln', 'NNP', 'I-NP', 'B-ORG']],
#  [['Swansea', 'NN', 'B-NP', 'B-ORG'],
#   ['1', 'CD', 'I-NP', 'O'],
#   ['Lincoln', 'NNP', 'I-NP', 'B-ORG']],
#  [['Swansea', 'NN', 'B-NP', 'B-ORG'],
#   ['1', 'CD', 'I-NP', 'O'],
#   ['Lincoln', 'NNP', 'I-NP', 'B-ORG']],
#  [['Swansea', 'NN', 'B-NP', 'B-ORG'],
#   ['1', 'CD', 'I-NP', 'O'],
#   ['Lincoln', 'NNP', 'I-NP', 'B-ORG']],
#  [['Swansea', 'NN', 'B-NP', 'B-ORG'],
#   ['1', 'CD', 'I-NP', 'O'],
#   ['Lincoln', 'NNP', 'I-NP', 'B-ORG']],
#  [['Swansea', 'NN', 'B-NP', 'B-ORG'],
#   ['1', 'CD', 'I-NP', 'O'],
#   ['Lincoln', 'NNP', 'I-NP', 'B-ORG']],
#  [['Swansea', 'NN', 'B-NP', 'B-ORG'],
#   ['1', 'CD', 'I-NP', 'O'],
#   ['Lincoln', 'NNP', 'I-NP', 'B-ORG']],
#  [['Swansea', 'NN', 'B-NP', 'B-ORG'],
#   ['1', 'CD', 'I-NP', 'O'],
#   ['Lincoln', 'NNP', 'I-NP', 'B-ORG']],
#  [['Swansea', 'NN', 'B-NP', 'B-ORG'],
#   ['1', 'CD', 'I-NP', 'O'],
#   ['Lincoln', 'NNP', 'I-NP', 'B-ORG']],
#  [['Swansea', 'NN', 'B-NP', 'B-ORG'],
#   ['1', 'CD', 'I-NP', 'O'],
#   ['Lincoln', 'NNP', 'I-NP', 'B-ORG']],
#  [['Swansea', 'NN', 'B-NP', 'B-ORG'],
#   ['1', 'CD', 'I-NP', 'O'],
#   ['Lincoln', 'NNP', 'I-NP', 'B-ORG']],
#  [['Swansea', 'NN', 'B-NP', 'B-ORG'],
#   ['1', 'CD', 'I-NP', 'O'],
#   ['Lincoln', 'NNP', 'I-NP', 'B-ORG']],
#  [['Swansea', 'NN', 'B-NP', 'B-ORG'],
#   ['1', 'CD', 'I-NP', 'O'],
#   ['Lincoln', 'NNP', 'I-NP', 'B-ORG']],
#  [['Swansea', 'NN', 'B-NP', 'B-ORG'],
#   ['1', 'CD', 'I-NP', 'O'],
#   ['Lincoln', 'NNP', 'I-NP', 'B-ORG']],
#  [['Swansea', 'NN', 'B-NP', 'B-ORG'],
#   ['1', 'CD', 'I-NP', 'O'],
#   ['Lincoln', 'NNP', 'I-NP', 'B-ORG']],
#  [['Swansea', 'NN', 'B-NP', 'B-ORG'],
#   ['1', 'CD', 'I-NP', 'O'],
#   ['Lincoln', 'NNP', 'I-NP', 'B-ORG']],
#  [['Swansea', 'NN', 'B-NP', 'B-ORG'],
#   ['1', 'CD', 'I-NP', 'O'],
#   ['Lincoln', 'NNP', 'I-NP', 'B-ORG']],
#  [['Swansea', 'NN', 'B-NP', 'B-ORG'],
#   ['1', 'CD', 'I-NP', 'O'],
#   ['Lincoln', 'NNP', 'I-NP', 'B-ORG']],
#  [['Swansea', 'NN', 'B-NP', 'B-ORG'],
#   ['1', 'CD', 'I-NP', 'O'],
#   ['Lincoln', 'NNP', 'I-NP', 'B-ORG']],
#  [['Swansea', 'NN', 'B-NP', 'B-ORG'],
#   ['1', 'CD', 'I-NP', 'O'],
#   ['Lincoln', 'NNP', 'I-NP', 'B-ORG']],
#  [['Swansea', 'NN', 'B-NP', 'B-ORG'],
#   ['1', 'CD', 'I-NP', 'O'],
#   ['Lincoln', 'NNP', 'I-NP', 'B-ORG']],
#  [['Swansea', 'NN', 'B-NP', 'B-ORG'],
#   ['1', 'CD', 'I-NP', 'O'],
#   ['Lincoln', 'NNP', 'I-NP', 'B-ORG']],
#  [['Swansea', 'NN', 'B-NP', 'B-ORG'],
#   ['1', 'CD', 'I-NP', 'O'],
#   ['Lincoln', 'NNP', 'I-NP', 'B-ORG']],
#  [['Swansea', 'NN', 'B-NP', 'B-ORG'],
#   ['1', 'CD', 'I-NP', 'O'],
#   ['Lincoln', 'NNP', 'I-NP', 'B-ORG']],
#  [['Swansea', 'NN', 'B-NP', 'B-ORG'],
#   ['1', 'CD', 'I-NP', 'O'],
#   ['Lincoln', 'NNP', 'I-NP', 'B-ORG']],
#  [['Swansea', 'NN', 'B-NP', 'B-ORG'],
#   ['1', 'CD', 'I-NP', 'O'],
#   ['Lincoln', 'NNP', 'I-NP', 'B-ORG']],
#  [['Swansea', 'NN', 'B-NP', 'B-ORG'],
#   ['1', 'CD', 'I-NP', 'O'],
#   ['Lincoln', 'NNP', 'I-NP', 'B-ORG']],
#  [['Swansea', 'NN', 'B-NP', 'B-ORG'],
#   ['1', 'CD', 'I-NP', 'O'],
#   ['Lincoln', 'NNP', 'I-NP', 'B-ORG']],
#  [['Swansea', 'NN', 'B-NP', 'B-ORG'],
#   ['1', 'CD', 'I-NP', 'O'],
#   ['Lincoln', 'NNP', 'I-NP', 'B-ORG']],
#  [['Swansea', 'NN', 'B-NP', 'B-ORG'],
#   ['1', 'CD', 'I-NP', 'O'],
#   ['Lincoln', 'NNP', 'I-NP', 'B-ORG']],
#  [['Swansea', 'NN', 'B-NP', 'B-ORG'],
#   ['1', 'CD', 'I-NP', 'O'],
#   ['Lincoln', 'NNP', 'I-NP', 'B-ORG']],
#  [['Swansea', 'NN', 'B-NP', 'B-ORG'],
#   ['1', 'CD', 'I-NP', 'O'],
#   ['Lincoln', 'NNP', 'I-NP', 'B-ORG']],
#  [['Swansea', 'NN', 'B-NP', 'B-ORG'],
#   ['1', 'CD', 'I-NP', 'O'],
#   ['Lincoln', 'NNP', 'I-NP', 'B-ORG']],
#  [['Swansea', 'NN', 'B-NP', 'B-ORG'],
#   ['1', 'CD', 'I-NP', 'O'],
#   ['Lincoln', 'NNP', 'I-NP', 'B-ORG']],
#  [['Swansea', 'NN', 'B-NP', 'B-ORG'],
#   ['1', 'CD', 'I-NP', 'O'],
#   ['Lincoln', 'NNP', 'I-NP', 'B-ORG']],
#  [['Swansea', 'NN', 'B-NP', 'B-ORG'],
#   ['1', 'CD', 'I-NP', 'O'],
#   ['Lincoln', 'NNP', 'I-NP', 'B-ORG']],
#  [['Swansea', 'NN', 'B-NP', 'B-ORG'],
#   ['1', 'CD', 'I-NP', 'O'],
#   ['Lincoln', 'NNP', 'I-NP', 'B-ORG']],
#  [['Swansea', 'NN', 'B-NP', 'B-ORG'],
#   ['1', 'CD', 'I-NP', 'O'],
#   ['Lincoln', 'NNP', 'I-NP', 'B-ORG']],
#  [['Swansea', 'NN', 'B-NP', 'B-ORG'],
#   ['1', 'CD', 'I-NP', 'O'],
#   ['Lincoln', 'NNP', 'I-NP', 'B-ORG']],
#  [['Swansea', 'NN', 'B-NP', 'B-ORG'],
#   ['1', 'CD', 'I-NP', 'O'],
#   ['Lincoln', 'NNP', 'I-NP', 'B-ORG']],
#  [['Swansea', 'NN', 'B-NP', 'B-ORG'],
#   ['1', 'CD', 'I-NP', 'O'],
#   ['Lincoln', 'NNP', 'I-NP', 'B-ORG']],
#  [['Swansea', 'NN', 'B-NP', 'B-ORG'],
#   ['1', 'CD', 'I-NP', 'O'],
#   ['Lincoln', 'NNP', 'I-NP', 'B-ORG']],
#  [['Swansea', 'NN', 'B-NP', 'B-ORG'],
#   ['1', 'CD', 'I-NP', 'O'],
#   ['Lincoln', 'NNP', 'I-NP', 'B-ORG']],
#  [['Swansea', 'NN', 'B-NP', 'B-ORG'],
#   ['1', 'CD', 'I-NP', 'O'],
#   ['Lincoln', 'NNP', 'I-NP', 'B-ORG']],
#  [['Swansea', 'NN', 'B-NP', 'B-ORG'],
#   ['1', 'CD', 'I-NP', 'O'],
#   ['Lincoln', 'NNP', 'I-NP', 'B-ORG']],
#  [['Swansea', 'NN', 'B-NP', 'B-ORG'],
#   ['1', 'CD', 'I-NP', 'O'],
#   ['Lincoln', 'NNP', 'I-NP', 'B-ORG']],
#  [['Swansea', 'NN', 'B-NP', 'B-ORG'],
#   ['1', 'CD', 'I-NP', 'O'],
#   ['Lincoln', 'NNP', 'I-NP', 'B-ORG']],
#  [['Swansea', 'NN', 'B-NP', 'B-ORG'],
#   ['1', 'CD', 'I-NP', 'O'],
#   ['Lincoln', 'NNP', 'I-NP', 'B-ORG']],
#  [['Swansea', 'NN', 'B-NP', 'B-ORG'],
#   ['1', 'CD', 'I-NP', 'O'],
#   ['Lincoln', 'NNP', 'I-NP', 'B-ORG']],
#  [['Swansea', 'NN', 'B-NP', 'B-ORG'],
#   ['1', 'CD', 'I-NP', 'O'],
#   ['Lincoln', 'NNP', 'I-NP', 'B-ORG']],
#  [['Swansea', 'NN', 'B-NP', 'B-ORG'],
#   ['1', 'CD', 'I-NP', 'O'],
#   ['Lincoln', 'NNP', 'I-NP', 'B-ORG']],
#  [['Swansea', 'NN', 'B-NP', 'B-ORG'],
#   ['1', 'CD', 'I-NP', 'O'],
#   ['Lincoln', 'NNP', 'I-NP', 'B-ORG']],
#  [['Swansea', 'NN', 'B-NP', 'B-ORG'],
#   ['1', 'CD', 'I-NP', 'O'],
#   ['Lincoln', 'NNP', 'I-NP', 'B-ORG']],
#  [['Swansea', 'NN', 'B-NP', 'B-ORG'],
#   ['1', 'CD', 'I-NP', 'O'],
#   ['Lincoln', 'NNP', 'I-NP', 'B-ORG']],
#  [['Swansea', 'NN', 'B-NP', 'B-ORG'],
#   ['1', 'CD', 'I-NP', 'O'],
#   ['Lincoln', 'NNP', 'I-NP', 'B-ORG']],
#  [['Swansea', 'NN', 'B-NP', 'B-ORG'],
#   ['1', 'CD', 'I-NP', 'O'],
#   ['Lincoln', 'NNP', 'I-NP', 'B-ORG']],
#  [['Swansea', 'NN', 'B-NP', 'B-ORG'],
#   ['1', 'CD', 'I-NP', 'O'],
#   ['Lincoln', 'NNP', 'I-NP', 'B-ORG']],
#  [['Swansea', 'NN', 'B-NP', 'B-ORG'],
#   ['1', 'CD', 'I-NP', 'O'],
#   ['Lincoln', 'NNP', 'I-NP', 'B-ORG']],
#  [['Swansea', 'NN', 'B-NP', 'B-ORG'],
#   ['1', 'CD', 'I-NP', 'O'],
#   ['Lincoln', 'NNP', 'I-NP', 'B-ORG']],
#  [['Swansea', 'NN', 'B-NP', 'B-ORG'],
#   ['1', 'CD', 'I-NP', 'O'],
#   ['Lincoln', 'NNP', 'I-NP', 'B-ORG']],
#  [['Swansea', 'NN', 'B-NP', 'B-ORG'],
#   ['1', 'CD', 'I-NP', 'O'],
#   ['Lincoln', 'NNP', 'I-NP', 'B-ORG']],
#  [['Swansea', 'NN', 'B-NP', 'B-ORG'],
#   ['1', 'CD', 'I-NP', 'O'],
#   ['Lincoln', 'NNP', 'I-NP', 'B-ORG']],
#  [['Swansea', 'NN', 'B-NP', 'B-ORG'],
#   ['1', 'CD', 'I-NP', 'O'],
#   ['Lincoln', 'NNP', 'I-NP', 'B-ORG']],
#  [['Swansea', 'NN', 'B-NP', 'B-ORG'],
#   ['1', 'CD', 'I-NP', 'O'],
#   ['Lincoln', 'NNP', 'I-NP', 'B-ORG']],
#  [['Swansea', 'NN', 'B-NP', 'B-ORG'],
#   ['1', 'CD', 'I-NP', 'O'],
#   ['Lincoln', 'NNP', 'I-NP', 'B-ORG']],
#  [['Swansea', 'NN', 'B-NP', 'B-ORG'],
#   ['1', 'CD', 'I-NP', 'O'],
#   ['Lincoln', 'NNP', 'I-NP', 'B-ORG']],
#  [['Swansea', 'NN', 'B-NP', 'B-ORG'],
#   ['1', 'CD', 'I-NP', 'O'],
#   ['Lincoln', 'NNP', 'I-NP', 'B-ORG']],
#  [['Swansea', 'NN', 'B-NP', 'B-ORG'],
#   ['1', 'CD', 'I-NP', 'O'],
#   ['Lincoln', 'NNP', 'I-NP', 'B-ORG']],
#  [['Swansea', 'NN', 'B-NP', 'B-ORG'],
#   ['1', 'CD', 'I-NP', 'O'],
#   ['Lincoln', 'NNP', 'I-NP', 'B-ORG']],
#  [['Swansea', 'NN', 'B-NP', 'B-ORG'],
#   ['1', 'CD', 'I-NP', 'O'],
#   ['Lincoln', 'NNP', 'I-NP', 'B-ORG']],
#  [['Swansea', 'NN', 'B-NP', 'B-ORG'],
#   ['1', 'CD', 'I-NP', 'O'],
#   ['Lincoln', 'NNP', 'I-NP', 'B-ORG']],
#  [['Swansea', 'NN', 'B-NP', 'B-ORG'],
#   ['1', 'CD', 'I-NP', 'O'],
#   ['Lincoln', 'NNP', 'I-NP', 'B-ORG']],
#  [['Swansea', 'NN', 'B-NP', 'B-ORG'],
#   ['1', 'CD', 'I-NP', 'O'],
#   ['Lincoln', 'NNP', 'I-NP', 'B-ORG']],
#  [['Swansea', 'NN', 'B-NP', 'B-ORG'],
#   ['1', 'CD', 'I-NP', 'O'],
#   ['Lincoln', 'NNP', 'I-NP', 'B-ORG']],
#  [['Swansea', 'NN', 'B-NP', 'B-ORG'],
#   ['1', 'CD', 'I-NP', 'O'],
#   ['Lincoln', 'NNP', 'I-NP', 'B-ORG']],
#  [['Swansea', 'NN', 'B-NP', 'B-ORG'],
#   ['1', 'CD', 'I-NP', 'O'],
#   ['Lincoln', 'NNP', 'I-NP', 'B-ORG']],
#  [['Swansea', 'NN', 'B-NP', 'B-ORG'],
#   ['1', 'CD', 'I-NP', 'O'],
#   ['Lincoln', 'NNP', 'I-NP', 'B-ORG']],
#  [['Swansea', 'NN', 'B-NP', 'B-ORG'],
#   ['1', 'CD', 'I-NP', 'O'],
#   ['Lincoln', 'NNP', 'I-NP', 'B-ORG']],
#  [['Swansea', 'NN', 'B-NP', 'B-ORG'],
#   ['1', 'CD', 'I-NP', 'O'],
#   ['Lincoln', 'NNP', 'I-NP', 'B-ORG']],
#  [['Swansea', 'NN', 'B-NP', 'B-ORG'],
#   ['1', 'CD', 'I-NP', 'O'],
#   ['Lincoln', 'NNP', 'I-NP', 'B-ORG']],
#  [['Swansea', 'NN', 'B-NP', 'B-ORG'],
#   ['1', 'CD', 'I-NP', 'O'],
#   ['Lincoln', 'NNP', 'I-NP', 'B-ORG']],
#  [['Swansea', 'NN', 'B-NP', 'B-ORG'],
#   ['1', 'CD', 'I-NP', 'O'],
#   ['Lincoln', 'NNP', 'I-NP', 'B-ORG']],
#  [['Swansea', 'NN', 'B-NP', 'B-ORG'],
#   ['1', 'CD', 'I-NP', 'O'],
#   ['Lincoln', 'NNP', 'I-NP', 'B-ORG']],
#  [['Swansea', 'NN', 'B-NP', 'B-ORG'],
#   ['1', 'CD', 'I-NP', 'O'],
#   ['Lincoln', 'NNP', 'I-NP', 'B-ORG']],
#  [['Swansea', 'NN', 'B-NP', 'B-ORG'],
#   ['1', 'CD', 'I-NP', 'O'],
#   ['Lincoln', 'NNP', 'I-NP', 'B-ORG']],
#  [['Swansea', 'NN', 'B-NP', 'B-ORG'],
#   ['1', 'CD', 'I-NP', 'O'],
#   ['Lincoln', 'NNP', 'I-NP', 'B-ORG']],
#  [['Swansea', 'NN', 'B-NP', 'B-ORG'],
#   ['1', 'CD', 'I-NP', 'O'],
#   ['Lincoln', 'NNP', 'I-NP', 'B-ORG']],
#  [['Swansea', 'NN', 'B-NP', 'B-ORG'],
#   ['1', 'CD', 'I-NP', 'O'],
#   ['Lincoln', 'NNP', 'I-NP', 'B-ORG']],
#  [['Swansea', 'NN', 'B-NP', 'B-ORG'],
#   ['1', 'CD', 'I-NP', 'O'],
#   ['Lincoln', 'NNP', 'I-NP', 'B-ORG']],
#  [['Swansea', 'NN', 'B-NP', 'B-ORG'],
#   ['1', 'CD', 'I-NP', 'O'],
#   ['Lincoln', 'NNP', 'I-NP', 'B-ORG']],
#  [['Swansea', 'NN', 'B-NP', 'B-ORG'],
#   ['1', 'CD', 'I-NP', 'O'],
#   ['Lincoln', 'NNP', 'I-NP', 'B-ORG']],
#  [['Swansea', 'NN', 'B-NP', 'B-ORG'],
#   ['1', 'CD', 'I-NP', 'O'],
#   ['Lincoln', 'NNP', 'I-NP', 'B-ORG']],
#  [['Swansea', 'NN', 'B-NP', 'B-ORG'],
#   ['1', 'CD', 'I-NP', 'O'],
#   ['Lincoln', 'NNP', 'I-NP', 'B-ORG']],
#  [['Swansea', 'NN', 'B-NP', 'B-ORG'],
#   ['1', 'CD', 'I-NP', 'O'],
#   ['Lincoln', 'NNP', 'I-NP', 'B-ORG']],
#  [['Swansea', 'NN', 'B-NP', 'B-ORG'],
#   ['1', 'CD', 'I-NP', 'O'],
#   ['Lincoln', 'NNP', 'I-NP', 'B-ORG']],
#  [['Swansea', 'NN', 'B-NP', 'B-ORG'],
#   ['1', 'CD', 'I-NP', 'O'],
#   ['Lincoln', 'NNP', 'I-NP', 'B-ORG']],
#  [['Swansea', 'NN', 'B-NP', 'B-ORG'],
#   ['1', 'CD', 'I-NP', 'O'],
#   ['Lincoln', 'NNP', 'I-NP', 'B-ORG']],
#  [['Swansea', 'NN', 'B-NP', 'B-ORG'],
#   ['1', 'CD', 'I-NP', 'O'],
#   ['Lincoln', 'NNP', 'I-NP', 'B-ORG']],
#  [['Swansea', 'NN', 'B-NP', 'B-ORG'],
#   ['1', 'CD', 'I-NP', 'O'],
#   ['Lincoln', 'NNP', 'I-NP', 'B-ORG']],
#  [['Swansea', 'NN', 'B-NP', 'B-ORG'],
#   ['1', 'CD', 'I-NP', 'O'],
#   ['Lincoln', 'NNP', 'I-NP', 'B-ORG']],
#  [['Swansea', 'NN', 'B-NP', 'B-ORG'],
#   ['1', 'CD', 'I-NP', 'O'],
#   ['Lincoln', 'NNP', 'I-NP', 'B-ORG']],
#  [['Swansea', 'NN', 'B-NP', 'B-ORG'],
#   ['1', 'CD', 'I-NP', 'O'],
#   ['Lincoln', 'NNP', 'I-NP', 'B-ORG']],
#  [['Swansea', 'NN', 'B-NP', 'B-ORG'],
#   ['1', 'CD', 'I-NP', 'O'],
#   ['Lincoln', 'NNP', 'I-NP', 'B-ORG']],
#  [['Swansea', 'NN', 'B-NP', 'B-ORG'],
#   ['1', 'CD', 'I-NP', 'O'],
#   ['Lincoln', 'NNP', 'I-NP', 'B-ORG']],
#  [['Swansea', 'NN', 'B-NP', 'B-ORG'],
#   ['1', 'CD', 'I-NP', 'O'],
#   ['Lincoln', 'NNP', 'I-NP', 'B-ORG']],
#  [['Swansea', 'NN', 'B-NP', 'B-ORG'],
#   ['1', 'CD', 'I-NP', 'O'],
#   ['Lincoln', 'NNP', 'I-NP', 'B-ORG']],
#  [['Swansea', 'NN', 'B-NP', 'B-ORG'],
#   ['1', 'CD', 'I-NP', 'O'],
#   ['Lincoln', 'NNP', 'I-NP', 'B-ORG']],
#  [['Swansea', 'NN', 'B-NP', 'B-ORG'],
#   ['1', 'CD', 'I-NP', 'O'],
#   ['Lincoln', 'NNP', 'I-NP', 'B-ORG']],
#  [['Swansea', 'NN', 'B-NP', 'B-ORG'],
#   ['1', 'CD', 'I-NP', 'O'],
#   ['Lincoln', 'NNP', 'I-NP', 'B-ORG']],
#  [['Swansea', 'NN', 'B-NP', 'B-ORG'],
#   ['1', 'CD', 'I-NP', 'O'],
#   ['Lincoln', 'NNP', 'I-NP', 'B-ORG']],
#  [['Swansea', 'NN', 'B-NP', 'B-ORG'],
#   ['1', 'CD', 'I-NP', 'O'],
#   ['Lincoln', 'NNP', 'I-NP', 'B-ORG']],
#  [['Swansea', 'NN', 'B-NP', 'B-ORG'],
#   ['1', 'CD', 'I-NP', 'O'],
#   ['Lincoln', 'NNP', 'I-NP', 'B-ORG']],
#  [['Swansea', 'NN', 'B-NP', 'B-ORG'],
#   ['1', 'CD', 'I-NP', 'O'],
#   ['Lincoln', 'NNP', 'I-NP', 'B-ORG']],
#  [['Swansea', 'NN', 'B-NP', 'B-ORG'],
#   ['1', 'CD', 'I-NP', 'O'],
#   ['Lincoln', 'NNP', 'I-NP', 'B-ORG']],
#  [['Swansea', 'NN', 'B-NP', 'B-ORG'],
#   ['1', 'CD', 'I-NP', 'O'],
#   ['Lincoln', 'NNP', 'I-NP', 'B-ORG']],
#  [['Swansea', 'NN', 'B-NP', 'B-ORG'],
#   ['1', 'CD', 'I-NP', 'O'],
#   ['Lincoln', 'NNP', 'I-NP', 'B-ORG']],
#  [['Swansea', 'NN', 'B-NP', 'B-ORG'],
#   ['1', 'CD', 'I-NP', 'O'],
#   ['Lincoln', 'NNP', 'I-NP', 'B-ORG']],
#  [['Swansea', 'NN', 'B-NP', 'B-ORG'],
#   ['1', 'CD', 'I-NP', 'O'],
#   ['Lincoln', 'NNP', 'I-NP', 'B-ORG']],
#  [['Swansea', 'NN', 'B-NP', 'B-ORG'],
#   ['1', 'CD', 'I-NP', 'O'],
#   ['Lincoln', 'NNP', 'I-NP', 'B-ORG']],
#  [['Swansea', 'NN', 'B-NP', 'B-ORG'],
#   ['1', 'CD', 'I-NP', 'O'],
#   ['Lincoln', 'NNP', 'I-NP', 'B-ORG']],
#  [['Swansea', 'NN', 'B-NP', 'B-ORG'],
#   ['1', 'CD', 'I-NP', 'O'],
#   ['Lincoln', 'NNP', 'I-NP', 'B-ORG']],
#  [['Swansea', 'NN', 'B-NP', 'B-ORG'],
#   ['1', 'CD', 'I-NP', 'O'],
#   ['Lincoln', 'NNP', 'I-NP', 'B-ORG']],
#  [['Swansea', 'NN', 'B-NP', 'B-ORG'],
#   ['1', 'CD', 'I-NP', 'O'],
#   ['Lincoln', 'NNP', 'I-NP', 'B-ORG']],
#  [['Swansea', 'NN', 'B-NP', 'B-ORG'],
#   ['1', 'CD', 'I-NP', 'O'],
#   ['Lincoln', 'NNP', 'I-NP', 'B-ORG']],
#  [['Swansea', 'NN', 'B-NP', 'B-ORG'],
#   ['1', 'CD', 'I-NP', 'O'],
#   ['Lincoln', 'NNP', 'I-NP', 'B-ORG']],
#  [['Swansea', 'NN', 'B-NP', 'B-ORG'],
#   ['1', 'CD', 'I-NP', 'O'],
#   ['Lincoln', 'NNP', 'I-NP', 'B-ORG']],
#  [['Swansea', 'NN', 'B-NP', 'B-ORG'],
#   ['1', 'CD', 'I-NP', 'O'],
#   ['Lincoln', 'NNP', 'I-NP', 'B-ORG']],
#  [['Swansea', 'NN', 'B-NP', 'B-ORG'],
#   ['1', 'CD', 'I-NP', 'O'],
#   ['Lincoln', 'NNP', 'I-NP', 'B-ORG']],
#  [['Swansea', 'NN', 'B-NP', 'B-ORG'],
#   ['1', 'CD', 'I-NP', 'O'],
#   ['Lincoln', 'NNP', 'I-NP', 'B-ORG']],
#  [['Swansea', 'NN', 'B-NP', 'B-ORG'],
#   ['1', 'CD', 'I-NP', 'O'],
#   ['Lincoln', 'NNP', 'I-NP', 'B-ORG']],
#  [['Swansea', 'NN', 'B-NP', 'B-ORG'],
#   ['1', 'CD', 'I-NP', 'O'],
#   ['Lincoln', 'NNP', 'I-NP', 'B-ORG']],
#  [['Swansea', 'NN', 'B-NP', 'B-ORG'],
#   ['1', 'CD', 'I-NP', 'O'],
#   ['Lincoln', 'NNP', 'I-NP', 'B-ORG']],
#  [['Swansea', 'NN', 'B-NP', 'B-ORG'],
#   ['1', 'CD', 'I-NP', 'O'],
#   ['Lincoln', 'NNP', 'I-NP', 'B-ORG']],
#  [['Swansea', 'NN', 'B-NP', 'B-ORG'],
#   ['1', 'CD', 'I-NP', 'O'],
#   ['Lincoln', 'NNP', 'I-NP', 'B-ORG']],
#  [['Swansea', 'NN', 'B-NP', 'B-ORG'],
#   ['1', 'CD', 'I-NP', 'O'],
#   ['Lincoln', 'NNP', 'I-NP', 'B-ORG']],
#  [['Swansea', 'NN', 'B-NP', 'B-ORG'],
#   ['1', 'CD', 'I-NP', 'O'],
#   ['Lincoln', 'NNP', 'I-NP', 'B-ORG']],
#  [['Swansea', 'NN', 'B-NP', 'B-ORG'],
#   ['1', 'CD', 'I-NP', 'O'],
#   ['Lincoln', 'NNP', 'I-NP', 'B-ORG']],
#  [['Swansea', 'NN', 'B-NP', 'B-ORG'],
#   ['1', 'CD', 'I-NP', 'O'],
#   ['Lincoln', 'NNP', 'I-NP', 'B-ORG']],
#  [['Swansea', 'NN', 'B-NP', 'B-ORG'],
#   ['1', 'CD', 'I-NP', 'O'],
#   ['Lincoln', 'NNP', 'I-NP', 'B-ORG']],
#  [['Swansea', 'NN', 'B-NP', 'B-ORG'],
#   ['1', 'CD', 'I-NP', 'O'],
#   ['Lincoln', 'NNP', 'I-NP', 'B-ORG']],
#  [['Swansea', 'NN', 'B-NP', 'B-ORG'],
#   ['1', 'CD', 'I-NP', 'O'],
#   ['Lincoln', 'NNP', 'I-NP', 'B-ORG']],
#  [['Swansea', 'NN', 'B-NP', 'B-ORG'],
#   ['1', 'CD', 'I-NP', 'O'],
#   ['Lincoln', 'NNP', 'I-NP', 'B-ORG']],
#  [['Swansea', 'NN', 'B-NP', 'B-ORG'],
#   ['1', 'CD', 'I-NP', 'O'],
#   ['Lincoln', 'NNP', 'I-NP', 'B-ORG']],
#  [['Swansea', 'NN', 'B-NP', 'B-ORG'],
#   ['1', 'CD', 'I-NP', 'O'],
#   ['Lincoln', 'NNP', 'I-NP', 'B-ORG']],
#  [['Swansea', 'NN', 'B-NP', 'B-ORG'],
#   ['1', 'CD', 'I-NP', 'O'],
#   ['Lincoln', 'NNP', 'I-NP', 'B-ORG']],
#  [['Swansea', 'NN', 'B-NP', 'B-ORG'],
#   ['1', 'CD', 'I-NP', 'O'],
#   ['Lincoln', 'NNP', 'I-NP', 'B-ORG']],
#  [['Swansea', 'NN', 'B-NP', 'B-ORG'],
#   ['1', 'CD', 'I-NP', 'O'],
#   ['Lincoln', 'NNP', 'I-NP', 'B-ORG']],
#  [['Swansea', 'NN', 'B-NP', 'B-ORG'],
#   ['1', 'CD', 'I-NP', 'O'],
#   ['Lincoln', 'NNP', 'I-NP', 'B-ORG']],
#  [['Swansea', 'NN', 'B-NP', 'B-ORG'],
#   ['1', 'CD', 'I-NP', 'O'],
#   ['Lincoln', 'NNP', 'I-NP', 'B-ORG']],
#  [['Swansea', 'NN', 'B-NP', 'B-ORG'],
#   ['1', 'CD', 'I-NP', 'O'],
#   ['Lincoln', 'NNP', 'I-NP', 'B-ORG']],
#  [['Swansea', 'NN', 'B-NP', 'B-ORG'],
#   ['1', 'CD', 'I-NP', 'O'],
#   ['Lincoln', 'NNP', 'I-NP', 'B-ORG']],
#  [['Swansea', 'NN', 'B-NP', 'B-ORG'],
#   ['1', 'CD', 'I-NP', 'O'],
#   ['Lincoln', 'NNP', 'I-NP', 'B-ORG']],
#  [['Swansea', 'NN', 'B-NP', 'B-ORG'],
#   ['1', 'CD', 'I-NP', 'O'],
#   ['Lincoln', 'NNP', 'I-NP', 'B-ORG']],
#  [['Swansea', 'NN', 'B-NP', 'B-ORG'],
#   ['1', 'CD', 'I-NP', 'O'],
#   ['Lincoln', 'NNP', 'I-NP', 'B-ORG']],
#  [['Swansea', 'NN', 'B-NP', 'B-ORG'],
#   ['1', 'CD', 'I-NP', 'O'],
#   ['Lincoln', 'NNP', 'I-NP', 'B-ORG']],
#  [['Swansea', 'NN', 'B-NP', 'B-ORG'],
#   ['1', 'CD', 'I-NP', 'O'],
#   ['Lincoln', 'NNP', 'I-NP', 'B-ORG']],
#  [['Swansea', 'NN', 'B-NP', 'B-ORG'],
#   ['1', 'CD', 'I-NP', 'O'],
#   ['Lincoln', 'NNP', 'I-NP', 'B-ORG']],
#  [['Swansea', 'NN', 'B-NP', 'B-ORG'],
#   ['1', 'CD', 'I-NP', 'O'],
#   ['Lincoln', 'NNP', 'I-NP', 'B-ORG']],
#  [['Swansea', 'NN', 'B-NP', 'B-ORG'],
#   ['1', 'CD', 'I-NP', 'O'],
#   ['Lincoln', 'NNP', 'I-NP', 'B-ORG']],
#  [['Swansea', 'NN', 'B-NP', 'B-ORG'],
#   ['1', 'CD', 'I-NP', 'O'],
#   ['Lincoln', 'NNP', 'I-NP', 'B-ORG']],
#  [['Swansea', 'NN', 'B-NP', 'B-ORG'],
#   ['1', 'CD', 'I-NP', 'O'],
#   ['Lincoln', 'NNP', 'I-NP', 'B-ORG']],
#  [['Swansea', 'NN', 'B-NP', 'B-ORG'],
#   ['1', 'CD', 'I-NP', 'O'],
#   ['Lincoln', 'NNP', 'I-NP', 'B-ORG']],
#  [['Swansea', 'NN', 'B-NP', 'B-ORG'],
#   ['1', 'CD', 'I-NP', 'O'],
#   ['Lincoln', 'NNP', 'I-NP', 'B-ORG']],
#  [['Swansea', 'NN', 'B-NP', 'B-ORG'],
#   ['1', 'CD', 'I-NP', 'O'],
#   ['Lincoln', 'NNP', 'I-NP', 'B-ORG']],
#  [['Swansea', 'NN', 'B-NP', 'B-ORG'],
#   ['1', 'CD', 'I-NP', 'O'],
#   ['Lincoln', 'NNP', 'I-NP', 'B-ORG']],
#  [['Swansea', 'NN', 'B-NP', 'B-ORG'],
#   ['1', 'CD', 'I-NP', 'O'],
#   ['Lincoln', 'NNP', 'I-NP', 'B-ORG']],
#  [['Swansea', 'NN', 'B-NP', 'B-ORG'],
#   ['1', 'CD', 'I-NP', 'O'],
#   ['Lincoln', 'NNP', 'I-NP', 'B-ORG']],
#  [['Swansea', 'NN', 'B-NP', 'B-ORG'],
#   ['1', 'CD', 'I-NP', 'O'],
#   ['Lincoln', 'NNP', 'I-NP', 'B-ORG']],
#  [['Swansea', 'NN', 'B-NP', 'B-ORG'],
#   ['1', 'CD', 'I-NP', 'O'],
#   ['Lincoln', 'NNP', 'I-NP', 'B-ORG']],
#  [['Swansea', 'NN', 'B-NP', 'B-ORG'],
#   ['1', 'CD', 'I-NP', 'O'],
#   ['Lincoln', 'NNP', 'I-NP', 'B-ORG']],
#  [['Swansea', 'NN', 'B-NP', 'B-ORG'],
#   ['1', 'CD', 'I-NP', 'O'],
#   ['Lincoln', 'NNP', 'I-NP', 'B-ORG']],
#  [['Swansea', 'NN', 'B-NP', 'B-ORG'],
#   ['1', 'CD', 'I-NP', 'O'],
#   ['Lincoln', 'NNP', 'I-NP', 'B-ORG']],
#  [['Swansea', 'NN', 'B-NP', 'B-ORG'],
#   ['1', 'CD', 'I-NP', 'O'],
#   ['Lincoln', 'NNP', 'I-NP', 'B-ORG']],
#  [['Swansea', 'NN', 'B-NP', 'B-ORG'],
#   ['1', 'CD', 'I-NP', 'O'],
#   ['Lincoln', 'NNP', 'I-NP', 'B-ORG']],
#  [['Swansea', 'NN', 'B-NP', 'B-ORG'],
#   ['1', 'CD', 'I-NP', 'O'],
#   ['Lincoln', 'NNP', 'I-NP', 'B-ORG']],
#  [['Swansea', 'NN', 'B-NP', 'B-ORG'],
#   ['1', 'CD', 'I-NP', 'O'],
#   ['Lincoln', 'NNP', 'I-NP', 'B-ORG']],
#  [['Swansea', 'NN', 'B-NP', 'B-ORG'],
#   ['1', 'CD', 'I-NP', 'O'],
#   ['Lincoln', 'NNP', 'I-NP', 'B-ORG']],
#  [['Swansea', 'NN', 'B-NP', 'B-ORG'],
#   ['1', 'CD', 'I-NP', 'O'],
#   ['Lincoln', 'NNP', 'I-NP', 'B-ORG']],
#  [['Swansea', 'NN', 'B-NP', 'B-ORG'],
#   ['1', 'CD', 'I-NP', 'O'],
#   ['Lincoln', 'NNP', 'I-NP', 'B-ORG']],
#  [['Swansea', 'NN', 'B-NP', 'B-ORG'],
#   ['1', 'CD', 'I-NP', 'O'],
#   ['Lincoln', 'NNP', 'I-NP', 'B-ORG']],
#  [['Swansea', 'NN', 'B-NP', 'B-ORG'],
#   ['1', 'CD', 'I-NP', 'O'],
#   ['Lincoln', 'NNP', 'I-NP', 'B-ORG']],
#  [['Swansea', 'NN', 'B-NP', 'B-ORG'],
#   ['1', 'CD', 'I-NP', 'O'],
#   ['Lincoln', 'NNP', 'I-NP', 'B-ORG']],
#  [['Swansea', 'NN', 'B-NP', 'B-ORG'],
#   ['1', 'CD', 'I-NP', 'O'],
#   ['Lincoln', 'NNP', 'I-NP', 'B-ORG']]]

# %%
# make syntactic block
new_document = []
for sentence in document[0:100]:
    new_sentence_list = []
    for token_list in sentence:
        if token_list[2] not in {'I-ADVP','I-ADJP','I-SBAR','I-PP','I-INTJ','I-CONJP','I-LST','I-VP','I-NP'} or token_list[2]==None: 
            new_sentence_list.append(new_token_list)
            new_token_list = [token_list[0],token_list[1],token_list[2]
        else:
            new_token_list[0] = new_token_list[0]+" "+token_list[0]
            new_token_list[2] = new_token_list[2]+" "+token_list[2]
        
    new_document.append(new_sentence_list)
    
# [[['EU', 'NNP_B-ORG', 'B-ORG'],
#   ['rejects', 'VBZ_O', 'O'],
#   ['German', 'JJ_B-MISC', 'B-MISC'],
#   ['call', 'NN_O', 'O'],...

# %%
    # ここで一つの疑問
    # 交換の割合はどのようにすべきだろうか？
    # (1)simple augmentを参照し確認
    # (2)とりあえず10% 30% 50% 70% 100%と順に試してみる => 先に作成してみましょ

# %%
# making dictonary object with label as key and token as value
label_token_dic = {}
for sentence in new_document:
    for token_list in sentence:
        label = token_list[1]
        token = token_list[0]
        if label not in label_token_dic:
            label_token_dic[label] = set()
        label_token_dic[label].add(token)
        
    #  {'NNP_B-ORG': {'Detroit',
    #   'FK',
    #   'ATRIA',
    #   'DBRS',...
    
    # label_token_dic.keys() でkey一覧取得可

# %%
    # 交換可能パタン
    # B，Iのみ　=> 固有表現に限定したsimple data augmantation
    # oも含む 　=> アノテーションラベル全体に範囲を広げたsimple data augmantation

# %%
    # ひとまずB，Iのみから作成

# %%
# making BI label list
BI_label_list = [label for label in list(label_token_dic.keys()) if "B-" in label or "I-" in label]
    # ['NNP_B-ORG',
    #  'JJ_B-MISC',
    #  'NNP_B-PER',
    #  'NNP_I-PER',

# %%
def Sent2str(sentence_list):
    return " ".join([token_list[0] for token_list in sentence_list])

def random_choice_token(token_set):
    n = random.randint(0,len(token_set)-1)
    token_list=list(token_set)
    return token_list[n]

# %%
import random
import csv


def SimpleDA_BI(n,filename):
    data_f_path = "data_augment/SimpleDA_BI/"+str(n)+"_"+filename+".txt"
    memo_f_path = "data_augment/SimpleDA_BI/"+str(n)+"_"+filename+"_memo.txt"
    with open(data_f_path,"w") as data_f, open(memo_f_path,"w") as memo_f:
        for now in range(n):
            if now%10 == 0:
                print('\r%d / %d' %(now, n), end='')

            x = random.randint(0,len(new_document)-1)
            origin_sentence = new_document[x]
            aug_sentence = []
            cnt = 0

            for token_list in origin_sentence:
                token = token_list[0]
                label = token_list[1]
                origin_label = token_list[2]

                if label in BI_label_list:
                    if len(label_token_dic[label])!=1:
                        token=random_choice_token(label_token_dic[label]-{token})
                        cnt = cnt + 1
                    

                aug_sentence.append([token,origin_label])
                data_f.write(" ".join([token,origin_label])+"\n")
            data_f.write("\n")

            memo_f.write(str(x)+"\t"+Sent2str(new_document[x])+"\n")
            memo_f.write(" "*len(str(x))+"\t"+Sent2str(aug_sentence)+"\n")
            memo_f.write("\n")
        
        memo_f.write(str(cnt)+"sentences augmented!!!! \n")

# %%
# #train
n = 15000

# %%
SimpleDA_BI(n*1,"train")
SimpleDA_BI(n*4,"train")
SimpleDA_BI(n*9,"train")
SimpleDA_BI(n*49,"train")
SimpleDA_BI(n*99,"train")
# Out:
# 1484990 / 1485000

# %% [markdown]
# ## valid

# %%
with open('data_original/valid.txt', 'r', encoding='UTF-8') as f:
    data = f.read()
    data = data.split("\n\n")
    data = data[1:3466]

# %%
# 以下同様
document = []
for sentence in data:#14988 sentences
    
    new_sentence_list = []
    sentence_list = sentence.split("\n")
    
    for token in sentence_list:
        token_list = token.split(" ")
        new_sentence_list.append(token_list)
    document.append(new_sentence_list)

new_document = []
for sentence in document:
    new_sentence_list = []
    for token_list in sentence:
        try:
            new_token_list = [token_list[0],token_list[1]+"_"+token_list[3],token_list[3]]
            new_sentence_list.append(new_token_list)
        except:
            pass
    new_document.append(new_sentence_list)

label_token_dic = {}
for sentence in new_document:
    for token_list in sentence:
        label = token_list[1]
        token = token_list[0]
        if label not in label_token_dic:
            label_token_dic[label] = set()
        label_token_dic[label].add(token)

        BI_label_list = [label for label in list(label_token_dic.keys()) if "B-" in label or "I-" in label]

BI_label_list = [label for label in list(label_token_dic.keys()) if "B-" in label or "I-" in label]

# %%
#valid
n = 3500

# %%
SimpleDA_BI(n*1,"valid")
SimpleDA_BI(n*4,"valid")
SimpleDA_BI(n*9,"valid")
SimpleDA_BI(n*49,"valid")
SimpleDA_BI(n*99,"valid")
# Out:
# 346490 / 346500
